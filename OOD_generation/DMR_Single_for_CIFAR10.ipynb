# %% [markdown]
# #### <b>Install the StyleGAN-XL Model</b>
#
# * For using the <b>StyleGAN-XL</b> model instance, the following libraries are required.
# * After installation, the <b>[Runtime Restart]</b> is recommended.

# %%
# Uninstall the current (new) JAX
# !pip uninstall jax jaxlib -y

# GPU front-end installation
# !pip install "jax[cuda11_cudnn805]==0.3.10" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

# Downgrade Pytorch for using the StyleGAN-XL
# !pip uninstall torch torchvision -y
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install timm==0.4.12 ftfy==6.1.1 ninja==1.10.2 opensimplex
# !pip install dill
# Out:
# Found existing installation: jax 0.4.14
# Uninstalling jax-0.4.14:
#   Successfully uninstalled jax-0.4.14
# Found existing installation: jaxlib 0.4.14+cuda11.cudnn86
# Uninstalling jaxlib-0.4.14+cuda11.cudnn86:
#   Successfully uninstalled jaxlib-0.4.14+cuda11.cudnn86
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Collecting jax[cuda11_cudnn805]==0.3.10
#   Downloading jax-0.3.10.tar.gz (939 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.7/939.7 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_cudnn805]==0.3.10) (1.4.0)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_cudnn805]==0.3.10) (1.23.5)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_cudnn805]==0.3.10) (3.3.0)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_cudnn805]==0.3.10) (1.10.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_cudnn805]==0.3.10) (4.7.1)
# Collecting jaxlib==0.3.10+cuda11.cudnn805 (from jax[cuda11_cudnn805]==0.3.10)
#   Downloading https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.3.10%2Bcuda11.cudnn805-cp310-none-manylinux2014_x86_64.whl (175.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.7/175.7 MB 2.5 MB/s eta 0:00:00
# Collecting flatbuffers<3.0,>=1.12 (from jaxlib==0.3.10+cuda11.cudnn805->jax[cuda11_cudnn805]==0.3.10)
#   Downloading flatbuffers-2.0.7-py2.py3-none-any.whl (26 kB)
# Building wheels for collected packages: jax
#   Building wheel for jax (setup.py) ... done
#   Created wheel for jax: filename=jax-0.3.10-py3-none-any.whl size=1088046 sha256=88d7494554185bbedde4d1b18d3c14251edfba36a261c1a57f25b1d73b03421c
#   Stored in directory: /root/.cache/pip/wheels/41/b8/74/0e87ee9c40aa5187c299d70fc5b0ceffcbb124175b8873eaed
# Successfully built jax
# Installing collected packages: flatbuffers, jaxlib, jax
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 23.5.26
#     Uninstalling flatbuffers-23.5.26:
#       Successfully uninstalled flatbuffers-23.5.26
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chex 0.1.7 requires jax>=0.4.6, but you have jax 0.3.10 which is incompatible.
# flax 0.7.2 requires jax>=0.4.2, but you have jax 0.3.10 which is incompatible.
# orbax-checkpoint 0.3.2 requires jax>=0.4.9, but you have jax 0.3.10 which is incompatible.
# tensorflow 2.12.0 requires jax>=0.3.15, but you have jax 0.3.10 which is incompatible.
# Successfully installed flatbuffers-2.0.7 jax-0.3.10 jaxlib-0.3.10+cuda11.cudnn805
# Found existing installation: torch 2.0.1+cu118
# Uninstalling torch-2.0.1+cu118:
#   Successfully uninstalled torch-2.0.1+cu118
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ERROR: Could not find a version that satisfies the requirement torch==1.9.0+cu111 (from versions: 1.11.0, 1.11.0+cpu, 1.11.0+cu102, 1.11.0+cu113, 1.11.0+cu115, 1.11.0+rocm4.3.1, 1.11.0+rocm4.5.2, 1.12.0, 1.12.0+cpu, 1.12.0+cu102, 1.12.0+cu113, 1.12.0+cu116, 1.12.0+rocm5.0, 1.12.0+rocm5.1.1, 1.12.1, 1.12.1+cpu, 1.12.1+cu102, 1.12.1+cu113, 1.12.1+cu116, 1.12.1+rocm5.0, 1.12.1+rocm5.1.1, 1.13.0, 1.13.0+cpu, 1.13.0+cu116, 1.13.0+cu117, 1.13.0+cu117.with.pypi.cudnn, 1.13.0+rocm5.1.1, 1.13.0+rocm5.2, 1.13.1, 1.13.1+cpu, 1.13.1+cu116, 1.13.1+cu117, 1.13.1+cu117.with.pypi.cudnn, 1.13.1+rocm5.1.1, 1.13.1+rocm5.2, 2.0.0, 2.0.0+cpu, 2.0.0+cpu.cxx11.abi, 2.0.0+cu117, 2.0.0+cu117.with.pypi.cudnn, 2.0.0+cu118, 2.0.0+rocm5.3, 2.0.0+rocm5.4.2, 2.0.1, 2.0.1+cpu, 2.0.1+cpu.cxx11.abi, 2.0.1+cu117, 2.0.1+cu117.with.pypi.cudnn, 2.0.1+cu118, 2.0.1+rocm5.3, 2.0.1+rocm5.4.2)
# ERROR: No matching distribution found for torch==1.9.0+cu111
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.0/377.0 kB 6.4 MB/s eta 0:00:00
# Collecting ftfy==6.1.1
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 6.3 MB/s eta 0:00:00
# Collecting ninja==1.10.2
#   Downloading ninja-1.10.2-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.1/108.1 kB 11.7 MB/s eta 0:00:00
# Collecting opensimplex
#   Downloading opensimplex-0.4.5-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.0/268.0 kB 27.3 MB/s eta 0:00:00
# Collecting torch>=1.4 (from timm==0.4.12)
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.7 MB/s eta 0:00:00
# Collecting torchvision (from timm==0.4.12)
#   Downloading torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 72.6 MB/s eta 0:00:00
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ftfy==6.1.1) (0.2.6)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from opensimplex) (1.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (3.1.2)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 45.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 52.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 73.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 3.0 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.1 MB/s eta 0:00:00
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 11.2 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 8.9 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 7.1 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 7.1 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch>=1.4->timm==0.4.12)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.4.12) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4->timm==0.4.12) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.4->timm==0.4.12) (0.41.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (3.27.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.4->timm==0.4.12) (16.0.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.4.12) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.4.12) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision->timm==0.4.12) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.4.12) (1.3.0)
# Installing collected packages: ninja, opensimplex, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, ftfy, nvidia-cusolver-cu11, nvidia-cudnn-cu11, torch, torchvision, timm
# Successfully installed ftfy-6.1.1 ninja-1.10.2 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 opensimplex-0.4.5 timm-0.4.12 torch-2.0.1 torchvision-0.15.2
# Collecting dill
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.7

# %%
# !wget https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EcPAsytGJQVEskKjrrfk-vkB-F2c7_6PigPqdkLR_bAsDQ?download=1 -O cifar10.pkl
# !git clone https://github.com/autonomousvision/stylegan-xl
# Out:
# --2023-08-11 16:47:44--  https://postechackr-my.sharepoint.com/:u:/g/personal/dongbinna_postech_ac_kr/EcPAsytGJQVEskKjrrfk-vkB-F2c7_6PigPqdkLR_bAsDQ?download=1
# Resolving postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)... 13.107.136.8, 2620:1ec:8f8::8
# Connecting to postechackr-my.sharepoint.com (postechackr-my.sharepoint.com)|13.107.136.8|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/dongbinna_postech_ac_kr/Documents/Research/models/StyleGAN_v2/cifar10.pkl?ga=1 [following]
# --2023-08-11 16:47:46--  https://postechackr-my.sharepoint.com/personal/dongbinna_postech_ac_kr/Documents/Research/models/StyleGAN_v2/cifar10.pkl?ga=1
# Reusing existing connection to postechackr-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 766269432 (731M) [application/octet-stream]
# Saving to: ‘cifar10.pkl’
#
# cifar10.pkl         100%[===================>] 730.77M  29.5MB/s    in 2m 37s
#
# 2023-08-11 16:50:23 (4.65 MB/s) - ‘cifar10.pkl’ saved [766269432/766269432]
#
# Cloning into 'stylegan-xl'...
# remote: Enumerating objects: 298, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 298 (delta 69), reused 48 (delta 48), pack-reused 216
# Receiving objects: 100% (298/298), 13.88 MiB | 32.29 MiB/s, done.
# Resolving deltas: 100% (140/140), done.

# %% [markdown]
# #### <b>Load the StyleGAN-XL Model</b>

# %%
import os
import sys

sys.path.append("./stylegan-xl")

# %%
# Copyright (c) 2021, NVIDIA CORPORATION & AFFILIATES.  All rights reserved.
"""Generate images using pretrained network pickle."""

import re
from typing import List, Optional, Tuple, Union

import click
import dnnlib
import numpy as np
import PIL.Image
import torch

import legacy
from torch_utils import gen_utils

#----------------------------------------------------------------------------

def parse_range(s: Union[str, List]) -> List[int]:
    '''Parse a comma separated list of numbers or ranges and return a list of ints.
    Example: '1,2,5-10' returns [1, 2, 5, 6, 7]
    '''
    if isinstance(s, list): return s
    ranges = []
    range_re = re.compile(r'^(\d+)-(\d+)$')
    for p in s.split(','):
        m = range_re.match(p)
        if m:
            ranges.extend(range(int(m.group(1)), int(m.group(2))+1))
        else:
            ranges.append(int(p))
    return ranges

#----------------------------------------------------------------------------

def parse_vec2(s: Union[str, Tuple[float, float]]) -> Tuple[float, float]:
    '''Parse a floating point 2-vector of syntax 'a,b'.
    Example:
        '0,1' returns (0,1)
    '''
    if isinstance(s, tuple): return s
    parts = s.split(',')
    if len(parts) == 2:
        return (float(parts[0]), float(parts[1]))
    raise ValueError(f'cannot parse 2-vector {s}')

#----------------------------------------------------------------------------

def make_transform(translate: Tuple[float,float], angle: float):
    m = np.eye(3)
    s = np.sin(angle/360.0*np.pi*2)
    c = np.cos(angle/360.0*np.pi*2)
    m[0][0] = c
    m[0][1] = s
    m[0][2] = translate[0]
    m[1][0] = -s
    m[1][1] = c
    m[1][2] = translate[1]
    return m

#----------------------------------------------------------------------------

# %%
import pickle

device = torch.device('cuda')

# Load the pre-trained StyleGAN model.
print('Loading networks from ...')
with dnnlib.util.open_url("./cifar10.pkl") as f:
    G = legacy.load_network_pkl(f)['G_ema']
    G = G.eval().requires_grad_(False).to(device)

# Construct an inverse rotation/translation matrix and pass it to the generator.
rotate = 0
translate = [0,0]

if hasattr(G.synthesis, 'input'):
    m = make_transform(translate, rotate)
    m = np.linalg.inv(m)
    G.synthesis.input.transform.copy_(torch.from_numpy(m))
# Out:
# Loading networks from ...

# %% [markdown]
# #### <b>Generate the Latent Bank (Average Latents)</b>

# %%
# Calculate the average latent vectors for each class.
batch_sz = 1
truncation_psi = 0
seed = 1234
centroids_path = None

class_centers = []
for class_idx in range(10):
    w = gen_utils.get_w_from_seed(G, batch_sz, device, truncation_psi, seed=seed, centroids_path=centroids_path, class_idx=class_idx)
    class_centers.append(w)
# Out:
# Setting up PyTorch plugin "bias_act_plugin"... Done.

# %% [markdown]
# #### <b>Generate the Synthesized OOD Images</b>

# %%
import time
import random

outdir = "./DMR/CIFAR10_OOD_training_images_using_DMR_single"
outdir_grid = "./DMR/CIFAR10_OOD_training_images_using_DMR_single_grid"

os.makedirs(outdir, exist_ok=True)
os.makedirs(outdir_grid, exist_ok=True)

made_cnt = 0
truncation_psi = 1.0
start_time = time.time()
max_iters = 625 # 625 X 8 X 10 = 50,000

for iter in range(max_iters):
    for class_idx in range(10):
        # Generate latent vectors whose size is the batch size.
        batch_sz = 8
        seed = random.randint(0, int(2 ** 32 - 1))

        # Single Latent Inversion (SLI)
        ws = gen_utils.get_w_from_seed(G, batch_sz, device, truncation_psi, seed=seed, centroids_path=centroids_path, class_idx=class_idx)
        ws = ws.to(device)
        ws -= class_centers[class_idx]

        # Strengthen the represenrtations with a probability of 50%.
        for i in range(len(ws)):
            random_data = random.randint(1, 2)
            if random_data == 1:
                ws[i] *= 3

        # Generate the images using the latent vectors.
        imgs = gen_utils.w_to_img(G, ws, to_np=True)

        # Save the grid image.
        seed = random.randint(0, int(2 ** 32 - 1))
        PIL.Image.fromarray(gen_utils.create_image_grid(imgs), 'RGB').save(f'{outdir_grid}/seed{seed}.png')

        # Save all images individually.
        for i, img in enumerate(imgs):
            PIL.Image.fromarray(gen_utils.create_image_grid(np.expand_dims(img, axis=0)), 'RGB').save(f'{outdir}/{made_cnt}.png')
            made_cnt += 1

        if (iter + 1) % 10 == 0:
            print(f"[{iter}/{max_iters}] {time.time() - start_time:.2f} seconds elapsed.")
# Out:
# Setting up PyTorch plugin "filtered_lrelu_plugin"... Done.
# [9/625] 202.20 seconds elapsed.
# [9/625] 202.30 seconds elapsed.
# [9/625] 202.41 seconds elapsed.
# [9/625] 202.51 seconds elapsed.
# [9/625] 202.61 seconds elapsed.
# [9/625] 202.71 seconds elapsed.
# [9/625] 202.82 seconds elapsed.
# [9/625] 202.92 seconds elapsed.
# [9/625] 203.03 seconds elapsed.
# [9/625] 203.13 seconds elapsed.
# [19/625] 212.29 seconds elapsed.
# [19/625] 212.39 seconds elapsed.
# [19/625] 212.49 seconds elapsed.
# [19/625] 212.59 seconds elapsed.
# [19/625] 212.69 seconds elapsed.
# [19/625] 212.79 seconds elapsed.
# [19/625] 212.89 seconds elapsed.
# [19/625] 213.00 seconds elapsed.
# [19/625] 213.10 seconds elapsed.
# [19/625] 213.20 seconds elapsed.
# [29/625] 222.48 seconds elapsed.
# [29/625] 222.58 seconds elapsed.
# [29/625] 222.68 seconds elapsed.
# [29/625] 222.79 seconds elapsed.
# [29/625] 222.88 seconds elapsed.
# [29/625] 222.99 seconds elapsed.
# [29/625] 223.09 seconds elapsed.
# [29/625] 223.19 seconds elapsed.
# [29/625] 223.29 seconds elapsed.
# [29/625] 223.39 seconds elapsed.
# [39/625] 232.65 seconds elapsed.
# [39/625] 232.75 seconds elapsed.
# [39/625] 232.86 seconds elapsed.
# [39/625] 232.96 seconds elapsed.
# [39/625] 233.07 seconds elapsed.
# [39/625] 233.18 seconds elapsed.
# [39/625] 233.28 seconds elapsed.
# [39/625] 233.39 seconds elapsed.
# [39/625] 233.50 seconds elapsed.
# [39/625] 233.60 seconds elapsed.
# [49/625] 242.86 seconds elapsed.
# [49/625] 242.96 seconds elapsed.
# [49/625] 243.06 seconds elapsed.
# [49/625] 243.16 seconds elapsed.
# [49/625] 243.27 seconds elapsed.
# [49/625] 243.37 seconds elapsed.
# [49/625] 243.47 seconds elapsed.
# [49/625] 243.57 seconds elapsed.
# [49/625] 243.67 seconds elapsed.
# [49/625] 243.77 seconds elapsed.
# [59/625] 253.11 seconds elapsed.
# [59/625] 253.21 seconds elapsed.
# [59/625] 253.31 seconds elapsed.
# [59/625] 253.41 seconds elapsed.
# [59/625] 253.52 seconds elapsed.
# [59/625] 253.62 seconds elapsed.
# [59/625] 253.72 seconds elapsed.
# [59/625] 253.82 seconds elapsed.
# [59/625] 253.92 seconds elapsed.
# [59/625] 254.03 seconds elapsed.
# [69/625] 263.37 seconds elapsed.
# [69/625] 263.47 seconds elapsed.
# [69/625] 263.59 seconds elapsed.
# [69/625] 263.69 seconds elapsed.
# [69/625] 263.80 seconds elapsed.
# [69/625] 263.91 seconds elapsed.
# [69/625] 264.02 seconds elapsed.
# [69/625] 264.12 seconds elapsed.
# [69/625] 264.24 seconds elapsed.
# [69/625] 264.34 seconds elapsed.
# [79/625] 273.56 seconds elapsed.
# [79/625] 273.67 seconds elapsed.
# [79/625] 273.77 seconds elapsed.
# [79/625] 273.87 seconds elapsed.
# [79/625] 273.98 seconds elapsed.
# [79/625] 274.08 seconds elapsed.
# [79/625] 274.18 seconds elapsed.
# [79/625] 274.28 seconds elapsed.
# [79/625] 274.40 seconds elapsed.
# [79/625] 274.50 seconds elapsed.
# [89/625] 283.91 seconds elapsed.
# [89/625] 284.01 seconds elapsed.
# [89/625] 284.12 seconds elapsed.
# [89/625] 284.22 seconds elapsed.
# [89/625] 284.32 seconds elapsed.
# [89/625] 284.43 seconds elapsed.
# [89/625] 284.53 seconds elapsed.
# [89/625] 284.64 seconds elapsed.
# [89/625] 284.74 seconds elapsed.
# [89/625] 284.84 seconds elapsed.
# [99/625] 294.28 seconds elapsed.
# [99/625] 294.39 seconds elapsed.
# [99/625] 294.49 seconds elapsed.
# [99/625] 294.60 seconds elapsed.
# [99/625] 294.70 seconds elapsed.
# [99/625] 294.80 seconds elapsed.
# [99/625] 294.91 seconds elapsed.
# [99/625] 295.01 seconds elapsed.
# [99/625] 295.12 seconds elapsed.
# [99/625] 295.22 seconds elapsed.
# [109/625] 304.57 seconds elapsed.
# [109/625] 304.68 seconds elapsed.
# [109/625] 304.79 seconds elapsed.
# [109/625] 304.89 seconds elapsed.
# [109/625] 305.00 seconds elapsed.
# [109/625] 305.11 seconds elapsed.
# [109/625] 305.22 seconds elapsed.
# [109/625] 305.32 seconds elapsed.
# [109/625] 305.43 seconds elapsed.
# [109/625] 305.54 seconds elapsed.
# [119/625] 315.01 seconds elapsed.
# [119/625] 315.12 seconds elapsed.
# [119/625] 315.23 seconds elapsed.
# [119/625] 315.33 seconds elapsed.
# [119/625] 315.43 seconds elapsed.
# [119/625] 315.54 seconds elapsed.
# [119/625] 315.64 seconds elapsed.
# [119/625] 315.74 seconds elapsed.
# [119/625] 315.85 seconds elapsed.
# [119/625] 315.95 seconds elapsed.
# [129/625] 325.50 seconds elapsed.
# [129/625] 325.60 seconds elapsed.
# [129/625] 325.71 seconds elapsed.
# [129/625] 325.81 seconds elapsed.
# [129/625] 325.92 seconds elapsed.
# [129/625] 326.02 seconds elapsed.
# [129/625] 326.13 seconds elapsed.
# [129/625] 326.23 seconds elapsed.
# [129/625] 326.33 seconds elapsed.
# [129/625] 326.44 seconds elapsed.
# [139/625] 335.93 seconds elapsed.
# [139/625] 336.04 seconds elapsed.
# [139/625] 336.15 seconds elapsed.
# [139/625] 336.26 seconds elapsed.
# [139/625] 336.36 seconds elapsed.
# [139/625] 336.47 seconds elapsed.
# [139/625] 336.58 seconds elapsed.
# [139/625] 336.69 seconds elapsed.
# [139/625] 336.80 seconds elapsed.
# [139/625] 336.91 seconds elapsed.
# [149/625] 346.44 seconds elapsed.
# [149/625] 346.55 seconds elapsed.
# [149/625] 346.66 seconds elapsed.
# [149/625] 346.76 seconds elapsed.
# [149/625] 346.88 seconds elapsed.
# [149/625] 346.98 seconds elapsed.
# [149/625] 347.09 seconds elapsed.
# [149/625] 347.20 seconds elapsed.
# [149/625] 347.31 seconds elapsed.
# [149/625] 347.42 seconds elapsed.
# [159/625] 357.17 seconds elapsed.
# [159/625] 357.28 seconds elapsed.
# [159/625] 357.38 seconds elapsed.
# [159/625] 357.49 seconds elapsed.
# [159/625] 357.59 seconds elapsed.
# [159/625] 357.70 seconds elapsed.
# [159/625] 357.81 seconds elapsed.
# [159/625] 357.91 seconds elapsed.
# [159/625] 358.02 seconds elapsed.
# [159/625] 358.12 seconds elapsed.
# [169/625] 367.75 seconds elapsed.
# [169/625] 367.86 seconds elapsed.
# [169/625] 367.97 seconds elapsed.
# [169/625] 368.08 seconds elapsed.
# [169/625] 368.19 seconds elapsed.
# [169/625] 368.29 seconds elapsed.
# [169/625] 368.40 seconds elapsed.
# [169/625] 368.51 seconds elapsed.
# [169/625] 368.62 seconds elapsed.
# [169/625] 368.73 seconds elapsed.
# [179/625] 378.25 seconds elapsed.
# [179/625] 378.36 seconds elapsed.
# [179/625] 378.46 seconds elapsed.
# [179/625] 378.57 seconds elapsed.
# [179/625] 378.67 seconds elapsed.
# [179/625] 378.78 seconds elapsed.
# [179/625] 378.89 seconds elapsed.
# [179/625] 379.00 seconds elapsed.
# [179/625] 379.11 seconds elapsed.
# [179/625] 379.22 seconds elapsed.
# [189/625] 388.89 seconds elapsed.
# [189/625] 389.00 seconds elapsed.
# [189/625] 389.11 seconds elapsed.
# [189/625] 389.21 seconds elapsed.
# [189/625] 389.32 seconds elapsed.
# [189/625] 389.42 seconds elapsed.
# [189/625] 389.53 seconds elapsed.
# [189/625] 389.63 seconds elapsed.
# [189/625] 389.74 seconds elapsed.
# [189/625] 389.85 seconds elapsed.
# [199/625] 399.54 seconds elapsed.
# [199/625] 399.65 seconds elapsed.
# [199/625] 399.76 seconds elapsed.
# [199/625] 399.86 seconds elapsed.
# [199/625] 399.97 seconds elapsed.
# [199/625] 400.08 seconds elapsed.
# [199/625] 400.18 seconds elapsed.
# [199/625] 400.29 seconds elapsed.
# [199/625] 400.39 seconds elapsed.
# [199/625] 400.50 seconds elapsed.
# [209/625] 410.08 seconds elapsed.
# [209/625] 410.19 seconds elapsed.
# [209/625] 410.31 seconds elapsed.
# [209/625] 410.41 seconds elapsed.
# [209/625] 410.52 seconds elapsed.
# [209/625] 410.63 seconds elapsed.
# [209/625] 410.74 seconds elapsed.
# [209/625] 410.85 seconds elapsed.
# [209/625] 410.96 seconds elapsed.
# [209/625] 411.07 seconds elapsed.
# [219/625] 420.72 seconds elapsed.
# [219/625] 420.83 seconds elapsed.
# [219/625] 420.93 seconds elapsed.
# [219/625] 421.04 seconds elapsed.
# [219/625] 421.15 seconds elapsed.
# [219/625] 421.25 seconds elapsed.
# [219/625] 421.36 seconds elapsed.
# [219/625] 421.47 seconds elapsed.
# [219/625] 421.57 seconds elapsed.
# [219/625] 421.68 seconds elapsed.
# [229/625] 431.40 seconds elapsed.
# [229/625] 431.51 seconds elapsed.
# [229/625] 431.61 seconds elapsed.
# [229/625] 431.72 seconds elapsed.
# [229/625] 431.83 seconds elapsed.
# [229/625] 431.93 seconds elapsed.
# [229/625] 432.04 seconds elapsed.
# [229/625] 432.14 seconds elapsed.
# [229/625] 432.25 seconds elapsed.
# [229/625] 432.36 seconds elapsed.
# [239/625] 442.04 seconds elapsed.
# [239/625] 442.15 seconds elapsed.
# [239/625] 442.26 seconds elapsed.
# [239/625] 442.36 seconds elapsed.
# [239/625] 442.47 seconds elapsed.
# [239/625] 442.58 seconds elapsed.
# [239/625] 442.69 seconds elapsed.
# [239/625] 442.80 seconds elapsed.
# [239/625] 442.91 seconds elapsed.
# [239/625] 443.02 seconds elapsed.
# [249/625] 452.66 seconds elapsed.
# [249/625] 452.77 seconds elapsed.
# [249/625] 452.87 seconds elapsed.
# [249/625] 452.98 seconds elapsed.
# [249/625] 453.09 seconds elapsed.
# [249/625] 453.19 seconds elapsed.
# [249/625] 453.30 seconds elapsed.
# [249/625] 453.41 seconds elapsed.
# [249/625] 453.51 seconds elapsed.
# [249/625] 453.62 seconds elapsed.
# [259/625] 463.57 seconds elapsed.
# [259/625] 463.68 seconds elapsed.
# [259/625] 463.78 seconds elapsed.
# [259/625] 463.89 seconds elapsed.
# [259/625] 463.99 seconds elapsed.
# [259/625] 464.10 seconds elapsed.
# [259/625] 464.20 seconds elapsed.
# [259/625] 464.31 seconds elapsed.
# [259/625] 464.42 seconds elapsed.
# [259/625] 464.52 seconds elapsed.
# [269/625] 475.16 seconds elapsed.
# [269/625] 475.27 seconds elapsed.
# [269/625] 475.37 seconds elapsed.
# [269/625] 475.48 seconds elapsed.
# [269/625] 475.59 seconds elapsed.
# [269/625] 475.69 seconds elapsed.
# [269/625] 475.80 seconds elapsed.
# [269/625] 475.91 seconds elapsed.
# [269/625] 476.02 seconds elapsed.
# [269/625] 476.13 seconds elapsed.
# [279/625] 485.82 seconds elapsed.
# [279/625] 485.93 seconds elapsed.
# [279/625] 486.04 seconds elapsed.
# [279/625] 486.14 seconds elapsed.
# [279/625] 486.25 seconds elapsed.
# [279/625] 486.36 seconds elapsed.
# [279/625] 486.47 seconds elapsed.
# [279/625] 486.58 seconds elapsed.
# [279/625] 486.69 seconds elapsed.
# [279/625] 486.80 seconds elapsed.
# [289/625] 496.52 seconds elapsed.
# [289/625] 496.63 seconds elapsed.
# [289/625] 496.73 seconds elapsed.
# [289/625] 496.84 seconds elapsed.
# [289/625] 496.95 seconds elapsed.
# [289/625] 497.05 seconds elapsed.
# [289/625] 497.16 seconds elapsed.
# [289/625] 497.27 seconds elapsed.
# [289/625] 497.37 seconds elapsed.
# [289/625] 497.48 seconds elapsed.
# [299/625] 507.25 seconds elapsed.
# [299/625] 507.36 seconds elapsed.
# [299/625] 507.47 seconds elapsed.
# [299/625] 507.57 seconds elapsed.
# [299/625] 507.68 seconds elapsed.
# [299/625] 507.79 seconds elapsed.
# [299/625] 507.89 seconds elapsed.
# [299/625] 508.00 seconds elapsed.
# [299/625] 508.11 seconds elapsed.
# [299/625] 508.21 seconds elapsed.
# [309/625] 517.94 seconds elapsed.
# [309/625] 518.05 seconds elapsed.
# [309/625] 518.16 seconds elapsed.
# [309/625] 518.27 seconds elapsed.
# [309/625] 518.38 seconds elapsed.
# [309/625] 518.49 seconds elapsed.
# [309/625] 518.60 seconds elapsed.
# [309/625] 518.71 seconds elapsed.
# [309/625] 518.82 seconds elapsed.
# [309/625] 518.93 seconds elapsed.
# [319/625] 528.62 seconds elapsed.
# [319/625] 528.73 seconds elapsed.
# [319/625] 528.84 seconds elapsed.
# [319/625] 528.94 seconds elapsed.
# [319/625] 529.05 seconds elapsed.
# [319/625] 529.15 seconds elapsed.
# [319/625] 529.26 seconds elapsed.
# [319/625] 529.37 seconds elapsed.
# [319/625] 529.47 seconds elapsed.
# [319/625] 529.58 seconds elapsed.
# [329/625] 539.35 seconds elapsed.
# [329/625] 539.46 seconds elapsed.
# [329/625] 539.56 seconds elapsed.
# [329/625] 539.67 seconds elapsed.
# [329/625] 539.78 seconds elapsed.
# [329/625] 539.89 seconds elapsed.
# [329/625] 540.00 seconds elapsed.
# [329/625] 540.10 seconds elapsed.
# [329/625] 540.21 seconds elapsed.
# [329/625] 540.31 seconds elapsed.
# [339/625] 550.08 seconds elapsed.
# [339/625] 550.19 seconds elapsed.
# [339/625] 550.30 seconds elapsed.
# [339/625] 550.41 seconds elapsed.
# [339/625] 550.52 seconds elapsed.
# [339/625] 550.62 seconds elapsed.
# [339/625] 550.73 seconds elapsed.
# [339/625] 550.84 seconds elapsed.
# [339/625] 550.94 seconds elapsed.
# [339/625] 551.05 seconds elapsed.
# [349/625] 560.69 seconds elapsed.
# [349/625] 560.80 seconds elapsed.
# [349/625] 560.92 seconds elapsed.
# [349/625] 561.03 seconds elapsed.
# [349/625] 561.13 seconds elapsed.
# [349/625] 561.24 seconds elapsed.
# [349/625] 561.35 seconds elapsed.
# [349/625] 561.46 seconds elapsed.
# [349/625] 561.57 seconds elapsed.
# [349/625] 561.68 seconds elapsed.
# [359/625] 571.43 seconds elapsed.
# [359/625] 571.54 seconds elapsed.
# [359/625] 571.64 seconds elapsed.
# [359/625] 571.75 seconds elapsed.
# [359/625] 571.86 seconds elapsed.
# [359/625] 571.96 seconds elapsed.
# [359/625] 572.07 seconds elapsed.
# [359/625] 572.18 seconds elapsed.
# [359/625] 572.28 seconds elapsed.
# [359/625] 572.39 seconds elapsed.
# [369/625] 582.16 seconds elapsed.
# [369/625] 582.26 seconds elapsed.
# [369/625] 582.37 seconds elapsed.
# [369/625] 582.48 seconds elapsed.
# [369/625] 582.58 seconds elapsed.
# [369/625] 582.69 seconds elapsed.
# [369/625] 582.79 seconds elapsed.
# [369/625] 582.90 seconds elapsed.
# [369/625] 583.01 seconds elapsed.
# [369/625] 583.11 seconds elapsed.
# [379/625] 592.93 seconds elapsed.
# [379/625] 593.04 seconds elapsed.
# [379/625] 593.15 seconds elapsed.
# [379/625] 593.27 seconds elapsed.
# [379/625] 593.38 seconds elapsed.
# [379/625] 593.49 seconds elapsed.
# [379/625] 593.60 seconds elapsed.
# [379/625] 593.71 seconds elapsed.
# [379/625] 593.82 seconds elapsed.
# [379/625] 593.94 seconds elapsed.
# [389/625] 603.66 seconds elapsed.
# [389/625] 603.77 seconds elapsed.
# [389/625] 603.88 seconds elapsed.
# [389/625] 603.98 seconds elapsed.
# [389/625] 604.09 seconds elapsed.
# [389/625] 604.19 seconds elapsed.
# [389/625] 604.30 seconds elapsed.
# [389/625] 604.40 seconds elapsed.
# [389/625] 604.51 seconds elapsed.
# [389/625] 604.62 seconds elapsed.
# [399/625] 614.39 seconds elapsed.
# [399/625] 614.50 seconds elapsed.
# [399/625] 614.61 seconds elapsed.
# [399/625] 614.71 seconds elapsed.
# [399/625] 614.82 seconds elapsed.
# [399/625] 614.93 seconds elapsed.
# [399/625] 615.04 seconds elapsed.
# [399/625] 615.14 seconds elapsed.
# [399/625] 615.25 seconds elapsed.
# [399/625] 615.35 seconds elapsed.
# [409/625] 625.05 seconds elapsed.
# [409/625] 625.16 seconds elapsed.
# [409/625] 625.27 seconds elapsed.
# [409/625] 625.38 seconds elapsed.
# [409/625] 625.49 seconds elapsed.
# [409/625] 625.60 seconds elapsed.
# [409/625] 625.72 seconds elapsed.
# [409/625] 625.82 seconds elapsed.
# [409/625] 625.93 seconds elapsed.
# [409/625] 626.04 seconds elapsed.
# [419/625] 635.74 seconds elapsed.
# [419/625] 635.84 seconds elapsed.
# [419/625] 635.95 seconds elapsed.
# [419/625] 636.06 seconds elapsed.
# [419/625] 636.16 seconds elapsed.
# [419/625] 636.27 seconds elapsed.
# [419/625] 636.38 seconds elapsed.
# [419/625] 636.48 seconds elapsed.
# [419/625] 636.59 seconds elapsed.
# [419/625] 636.70 seconds elapsed.
# [429/625] 646.48 seconds elapsed.
# [429/625] 646.59 seconds elapsed.
# [429/625] 646.70 seconds elapsed.
# [429/625] 646.80 seconds elapsed.
# [429/625] 646.91 seconds elapsed.
# [429/625] 647.02 seconds elapsed.
# [429/625] 647.12 seconds elapsed.
# [429/625] 647.23 seconds elapsed.
# [429/625] 647.34 seconds elapsed.
# [429/625] 647.44 seconds elapsed.
# [439/625] 657.20 seconds elapsed.
# [439/625] 657.31 seconds elapsed.
# [439/625] 657.42 seconds elapsed.
# [439/625] 657.53 seconds elapsed.
# [439/625] 657.64 seconds elapsed.
# [439/625] 657.75 seconds elapsed.
# [439/625] 657.86 seconds elapsed.
# [439/625] 657.97 seconds elapsed.
# [439/625] 658.08 seconds elapsed.
# [439/625] 658.19 seconds elapsed.
# [449/625] 667.83 seconds elapsed.
# [449/625] 667.94 seconds elapsed.
# [449/625] 668.04 seconds elapsed.
# [449/625] 668.15 seconds elapsed.
# [449/625] 668.26 seconds elapsed.
# [449/625] 668.37 seconds elapsed.
# [449/625] 668.47 seconds elapsed.
# [449/625] 668.58 seconds elapsed.
# [449/625] 668.70 seconds elapsed.
# [449/625] 668.81 seconds elapsed.
# [459/625] 678.57 seconds elapsed.
# [459/625] 678.68 seconds elapsed.
# [459/625] 678.78 seconds elapsed.
# [459/625] 678.89 seconds elapsed.
# [459/625] 678.99 seconds elapsed.
# [459/625] 679.10 seconds elapsed.
# [459/625] 679.21 seconds elapsed.
# [459/625] 679.31 seconds elapsed.
# [459/625] 679.42 seconds elapsed.
# [459/625] 679.52 seconds elapsed.
# [469/625] 689.30 seconds elapsed.
# [469/625] 689.40 seconds elapsed.
# [469/625] 689.51 seconds elapsed.
# [469/625] 689.62 seconds elapsed.
# [469/625] 689.72 seconds elapsed.
# [469/625] 689.83 seconds elapsed.
# [469/625] 689.94 seconds elapsed.
# [469/625] 690.04 seconds elapsed.
# [469/625] 690.15 seconds elapsed.
# [469/625] 690.26 seconds elapsed.
# [479/625] 699.93 seconds elapsed.
# [479/625] 700.04 seconds elapsed.
# [479/625] 700.15 seconds elapsed.
# [479/625] 700.26 seconds elapsed.
# [479/625] 700.37 seconds elapsed.
# [479/625] 700.48 seconds elapsed.
# [479/625] 700.59 seconds elapsed.
# [479/625] 700.70 seconds elapsed.
# [479/625] 700.81 seconds elapsed.
# [479/625] 700.92 seconds elapsed.
# [489/625] 710.65 seconds elapsed.
# [489/625] 710.76 seconds elapsed.
# [489/625] 710.87 seconds elapsed.
# [489/625] 710.97 seconds elapsed.
# [489/625] 711.08 seconds elapsed.
# [489/625] 711.18 seconds elapsed.
# [489/625] 711.29 seconds elapsed.
# [489/625] 711.40 seconds elapsed.
# [489/625] 711.51 seconds elapsed.
# [489/625] 711.62 seconds elapsed.
# [499/625] 721.39 seconds elapsed.
# [499/625] 721.50 seconds elapsed.
# [499/625] 721.61 seconds elapsed.
# [499/625] 721.71 seconds elapsed.
# [499/625] 721.82 seconds elapsed.
# [499/625] 721.93 seconds elapsed.
# [499/625] 722.03 seconds elapsed.
# [499/625] 722.14 seconds elapsed.
# [499/625] 722.25 seconds elapsed.
# [499/625] 722.35 seconds elapsed.
# [509/625] 732.05 seconds elapsed.
# [509/625] 732.16 seconds elapsed.
# [509/625] 732.27 seconds elapsed.
# [509/625] 732.38 seconds elapsed.
# [509/625] 732.49 seconds elapsed.
# [509/625] 732.60 seconds elapsed.
# [509/625] 732.71 seconds elapsed.
# [509/625] 732.82 seconds elapsed.
# [509/625] 732.93 seconds elapsed.
# [509/625] 733.04 seconds elapsed.
# [519/625] 742.73 seconds elapsed.
# [519/625] 742.83 seconds elapsed.
# [519/625] 742.94 seconds elapsed.
# [519/625] 743.05 seconds elapsed.
# [519/625] 743.15 seconds elapsed.
# [519/625] 743.26 seconds elapsed.
# [519/625] 743.37 seconds elapsed.
# [519/625] 743.47 seconds elapsed.
# [519/625] 743.58 seconds elapsed.
# [519/625] 743.68 seconds elapsed.
# [529/625] 753.45 seconds elapsed.
# [529/625] 753.55 seconds elapsed.
# [529/625] 753.66 seconds elapsed.
# [529/625] 753.77 seconds elapsed.
# [529/625] 753.88 seconds elapsed.
# [529/625] 753.98 seconds elapsed.
# [529/625] 754.09 seconds elapsed.
# [529/625] 754.19 seconds elapsed.
# [529/625] 754.30 seconds elapsed.
# [529/625] 754.41 seconds elapsed.
# [539/625] 764.15 seconds elapsed.
# [539/625] 764.26 seconds elapsed.
# [539/625] 764.37 seconds elapsed.
# [539/625] 764.48 seconds elapsed.
# [539/625] 764.59 seconds elapsed.
# [539/625] 764.70 seconds elapsed.
# [539/625] 764.81 seconds elapsed.
# [539/625] 764.92 seconds elapsed.
# [539/625] 765.03 seconds elapsed.
# [539/625] 765.14 seconds elapsed.
# [549/625] 774.80 seconds elapsed.
# [549/625] 774.91 seconds elapsed.
# [549/625] 775.01 seconds elapsed.
# [549/625] 775.12 seconds elapsed.
# [549/625] 775.23 seconds elapsed.
# [549/625] 775.33 seconds elapsed.
# [549/625] 775.44 seconds elapsed.
# [549/625] 775.55 seconds elapsed.
# [549/625] 775.66 seconds elapsed.
# [549/625] 775.77 seconds elapsed.
# [559/625] 785.55 seconds elapsed.
# [559/625] 785.66 seconds elapsed.
# [559/625] 785.76 seconds elapsed.
# [559/625] 785.87 seconds elapsed.
# [559/625] 785.98 seconds elapsed.
# [559/625] 786.08 seconds elapsed.
# [559/625] 786.19 seconds elapsed.
# [559/625] 786.30 seconds elapsed.
# [559/625] 786.40 seconds elapsed.
# [559/625] 786.51 seconds elapsed.
# [569/625] 796.29 seconds elapsed.
# [569/625] 796.40 seconds elapsed.
# [569/625] 796.50 seconds elapsed.
# [569/625] 796.61 seconds elapsed.
# [569/625] 796.72 seconds elapsed.
# [569/625] 796.82 seconds elapsed.
# [569/625] 796.93 seconds elapsed.
# [569/625] 797.04 seconds elapsed.
# [569/625] 797.15 seconds elapsed.
# [569/625] 797.25 seconds elapsed.
# [579/625] 806.91 seconds elapsed.
# [579/625] 807.02 seconds elapsed.
# [579/625] 807.13 seconds elapsed.
# [579/625] 807.24 seconds elapsed.
# [579/625] 807.35 seconds elapsed.
# [579/625] 807.46 seconds elapsed.
# [579/625] 807.57 seconds elapsed.
# [579/625] 807.68 seconds elapsed.
# [579/625] 807.79 seconds elapsed.
# [579/625] 807.90 seconds elapsed.
# [589/625] 817.64 seconds elapsed.
# [589/625] 817.75 seconds elapsed.
# [589/625] 817.86 seconds elapsed.
# [589/625] 817.97 seconds elapsed.
# [589/625] 818.07 seconds elapsed.
# [589/625] 818.18 seconds elapsed.
# [589/625] 818.29 seconds elapsed.
# [589/625] 818.39 seconds elapsed.
# [589/625] 818.50 seconds elapsed.
# [589/625] 818.61 seconds elapsed.
# [599/625] 828.45 seconds elapsed.
# [599/625] 828.56 seconds elapsed.
# [599/625] 828.67 seconds elapsed.
# [599/625] 828.78 seconds elapsed.
# [599/625] 828.89 seconds elapsed.
# [599/625] 829.00 seconds elapsed.
# [599/625] 829.11 seconds elapsed.
# [599/625] 829.22 seconds elapsed.
# [599/625] 829.33 seconds elapsed.
# [599/625] 829.44 seconds elapsed.
# [609/625] 839.19 seconds elapsed.
# [609/625] 839.30 seconds elapsed.
# [609/625] 839.41 seconds elapsed.
# [609/625] 839.52 seconds elapsed.
# [609/625] 839.63 seconds elapsed.
# [609/625] 839.74 seconds elapsed.
# [609/625] 839.85 seconds elapsed.
# [609/625] 839.96 seconds elapsed.
# [609/625] 840.07 seconds elapsed.
# [609/625] 840.18 seconds elapsed.
# [619/625] 849.89 seconds elapsed.
# [619/625] 850.00 seconds elapsed.
# [619/625] 850.10 seconds elapsed.
# [619/625] 850.21 seconds elapsed.
# [619/625] 850.32 seconds elapsed.
# [619/625] 850.42 seconds elapsed.
# [619/625] 850.53 seconds elapsed.
# [619/625] 850.64 seconds elapsed.
# [619/625] 850.74 seconds elapsed.
# [619/625] 850.85 seconds elapsed.

# %%
# !find ./DMR/CIFAR10_OOD_training_images_using_DMR_single -type f | wc -l
# !find ./DMR/CIFAR10_OOD_training_images_using_DMR_single_grid -type f | wc -l
# Out:
# 50000
# 6250

# %%
# !zip -r ./CIFAR10_OOD_training_images_using_DMR_single.zip ./DMR/CIFAR10_OOD_training_images_using_DMR_single
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46235.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38343.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33711.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12495.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25493.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28667.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4836.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11969.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27820.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2407.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43564.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38409.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35044.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15032.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36164.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3883.png (deflated 11%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33373.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32877.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25436.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44703.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48657.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23607.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19253.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4637.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4411.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44826.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39853.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1353.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28206.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11968.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28370.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37322.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42739.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19457.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14741.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27537.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40892.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16992.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16181.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37946.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24134.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45637.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11954.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48205.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26535.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28983.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35266.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43664.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49079.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19393.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40382.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37128.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22663.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4652.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11910.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5014.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43738.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25598.png (deflated 12%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45344.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25235.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47441.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35633.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21956.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26723.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17791.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43412.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17394.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/569.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35047.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27289.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8267.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16011.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35683.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46996.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31910.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32102.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30173.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7012.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3660.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17736.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20465.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15828.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8840.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47566.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48120.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37174.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31141.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22020.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16721.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20346.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26887.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1280.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19379.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13041.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15110.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26897.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36638.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13667.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43556.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14203.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/977.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38121.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18954.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16561.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3416.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42915.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32801.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22866.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20008.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11242.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15458.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23080.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7784.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28013.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4742.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44484.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40355.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3432.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5261.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38825.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17997.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29241.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8399.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40782.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46350.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49436.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27122.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39937.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12247.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18060.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43063.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17459.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31151.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47018.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45537.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35694.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27905.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19839.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29167.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17188.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17657.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46937.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40416.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37009.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40266.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10182.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11223.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26486.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30515.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15920.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17022.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25803.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3020.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7549.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24108.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41538.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32191.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23697.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/294.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41504.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27229.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12308.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21489.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31711.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41868.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14707.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39613.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31757.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17666.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4844.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34062.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19250.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45409.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8857.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29428.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26137.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10776.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17709.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1805.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9665.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43989.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12240.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37634.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18331.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29453.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44547.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12809.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49163.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25334.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48308.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40204.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14209.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6184.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18476.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47936.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27006.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37924.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6148.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6947.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8769.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8327.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39178.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/336.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45076.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26776.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38471.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9103.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5669.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22486.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7275.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20429.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49371.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14917.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9432.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26140.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7858.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20668.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37228.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32002.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21082.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40603.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26990.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38647.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6575.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49202.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13976.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3258.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41158.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13499.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11084.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38066.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16750.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27150.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9076.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2177.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45103.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4211.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46928.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35203.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29864.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9984.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42385.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28327.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26195.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30325.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2547.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11536.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41864.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29260.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34996.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41557.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3525.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43856.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5875.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10294.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6764.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31538.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6247.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24911.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2349.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14936.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47875.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2522.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32811.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19167.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10694.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27635.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37221.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8971.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39165.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19797.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22232.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43829.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40935.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44022.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46968.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/870.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35687.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39251.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36184.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12871.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33548.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9530.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42940.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41825.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8544.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40315.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22330.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38103.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24067.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39272.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43784.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7470.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7384.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30911.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13774.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42910.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44249.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5129.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41230.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26493.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1883.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8256.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2683.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8658.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16360.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9613.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5610.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8443.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33094.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1585.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39839.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27724.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30670.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38486.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48875.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47464.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43003.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46467.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46332.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33117.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48603.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17515.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18062.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17235.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12868.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3142.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19112.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15172.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10737.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38350.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36435.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3259.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23148.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7362.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/565.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42731.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41682.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20937.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23330.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21883.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4143.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22862.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39561.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37239.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45600.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42678.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7318.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47146.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/418.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42569.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19661.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8412.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27737.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16199.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46314.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33940.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35003.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3116.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1987.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12674.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39034.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/130.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22057.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17853.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2509.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13981.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24344.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14529.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37404.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28203.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25627.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47869.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15361.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47397.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14842.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15389.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/830.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10623.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47668.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16421.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42543.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35766.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14434.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/948.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32780.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25959.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38174.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43264.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47914.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32259.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16969.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21512.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14997.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6480.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26393.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34767.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7273.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7656.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10366.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41191.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46365.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28358.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43531.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33975.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49171.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11651.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10105.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44812.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15863.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42729.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46551.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46867.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28165.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2044.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/778.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/195.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14833.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32103.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7072.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20114.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1688.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4134.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45741.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38879.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44600.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3046.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22389.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29257.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30227.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/476.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14345.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15927.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32404.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32904.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17717.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4928.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26079.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48008.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/673.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5223.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28897.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5633.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23331.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31027.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28685.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25789.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7370.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40081.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15308.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6351.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15598.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32574.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49236.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7458.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31737.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36812.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22482.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6724.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26976.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32263.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27975.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17443.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40733.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26473.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28896.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18057.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40439.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25539.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49367.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42429.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/515.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26338.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10149.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39769.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3785.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27514.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42190.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15119.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14389.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38990.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4547.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39269.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29159.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34148.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6265.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48666.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11161.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21909.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20924.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38882.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31449.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30146.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14908.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13291.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31318.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19181.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6333.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31004.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35038.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32785.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29512.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20642.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49675.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15051.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37114.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10720.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1487.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34372.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40768.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2954.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3528.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6362.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38827.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40251.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26087.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15671.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12795.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31807.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28046.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7916.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30129.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13890.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32157.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32307.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/974.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49564.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48477.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32187.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2819.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41070.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/958.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43400.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43491.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12730.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14992.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12717.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15362.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20719.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48789.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28632.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3170.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46501.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24881.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26745.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40103.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43641.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6614.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8550.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10531.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17903.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38035.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39638.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39229.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49832.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45755.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45652.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39491.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18870.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26692.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37645.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8539.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29133.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48975.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5189.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8335.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42317.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47224.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6371.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14918.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15291.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9857.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12137.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33907.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35004.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45769.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6471.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15207.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13510.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33136.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21913.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10353.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29236.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43177.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37599.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44348.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28374.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37666.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30351.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26641.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39098.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41399.png (stored 0%)
# ...
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29835.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35699.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30797.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8054.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45125.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38122.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7429.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18447.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44470.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1124.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21332.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49040.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7245.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40238.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13781.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25357.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47911.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34219.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36569.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11057.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9517.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14065.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22870.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45488.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41024.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27492.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16770.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24189.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27460.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6634.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36830.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/936.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1926.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10593.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13714.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7181.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15057.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47294.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24461.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38453.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18436.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47691.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26686.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27687.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12525.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17163.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39458.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40228.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/7727.png (deflated 9%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20095.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42650.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34807.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32771.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1356.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28268.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29059.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4446.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30071.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4048.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20871.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23250.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22997.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/31619.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29763.png (deflated 10%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48231.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38270.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19844.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17924.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22289.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27305.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34816.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15702.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44199.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20179.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22438.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3772.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37147.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16834.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6564.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18013.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36981.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27059.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36544.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/44362.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3399.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8158.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13411.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14768.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6627.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16329.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36920.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/13313.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43090.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43939.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20164.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29411.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/8989.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23259.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20801.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1586.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/42307.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38469.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15959.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19765.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/41506.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27079.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48599.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48171.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27988.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9312.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6782.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30483.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35265.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22627.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/1675.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21467.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21474.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4576.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25444.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9880.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/48079.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21963.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6995.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25460.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35504.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46999.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10195.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/46542.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24663.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6526.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33044.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36102.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4114.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35654.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14653.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/5965.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/2778.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36568.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25003.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14029.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/20011.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/34128.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/10886.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/17633.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/37023.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/26595.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36775.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/9774.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23479.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/24307.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21324.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19441.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/30711.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/43886.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/47003.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16117.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11300.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/38707.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49745.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12160.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3362.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45718.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/15686.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35569.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25315.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/14208.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49014.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/35969.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28281.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28537.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/16173.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3285.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/33771.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/11006.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/3415.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12649.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/39896.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/45942.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/19858.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/21042.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6010.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/32458.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/40975.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/22872.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/27703.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/18897.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/12402.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/29525.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/28577.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/23774.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/36461.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49053.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4661.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/49095.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/4812.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/25759.png (stored 0%)
#   adding: DMR/CIFAR10_OOD_training_images_using_DMR_single/6591.png (stored 0%)
